# %%
import pandas as pd
import numpy as np
import seaborn as sns

col_names =["vendor name","model","MCYT","MMIN","MMAX","CACH","CHMIN","CHMAX","PRP","ERP"]
data = pd.read_csv("machine.data",delimiter=",",header=None,names=col_names)
data
# Out:
#     vendor name          model  MCYT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ...

# %%
data = data.iloc[:,2:9]
data.describe()
# Out:
#               MCYT          MMIN          MMAX        CACH       CHMIN  \
# count   209.000000    209.000000    209.000000  209.000000  209.000000
# mean    203.822967   2867.980861  11796.153110   25.205742    4.698565
# std     260.262926   3878.742758  11726.564377   40.628722    6.816274
# min      17.000000     64.000000     64.000000    0.000000    0.000000
# 25%      50.000000    768.000000   4000.000000    0.000000    1.000000
# 50%     110.000000   2000.000000   8000.000000    8.000000    2.000000
# 75%     225.000000   4000.000000  16000.000000   32.000000    6.000000
# max    1500.000000  32000.000000  64000.000000  256.000000   52.000000
#
#             CHMAX          PRP
# count  209.000000   209.000000
# mean    18.267943   105.622010
# std     25.997318   160.830733
# min      0.000000     6.000000
# 25%      5.000000    27.000000
# 50%      8.000000    50.000000
# 75%     24.000000   113.000000
# max    176.000000  1150.000000

# %%
pd.isnull(data).mean()
# Out:
# MCYT     0.0
# MMIN     0.0
# MMAX     0.0
# CACH     0.0
# CHMIN    0.0
# CHMAX    0.0
# PRP      0.0
# dtype: float64

# %%
sns.heatmap(data.corr().abs(),annot=True)

# %%
data = data.iloc[:,[1,2,3,6]]
data
# Out:
#      MMIN   MMAX  CACH  PRP
# 0     256   6000   256  198
# 1    8000  32000    32  269
# 2    8000  32000    32  220
# 3    8000  32000    32  172
# 4    8000  16000    32  132
# ..    ...    ...   ...  ...
# 204  1000   8000     0   42
# 205  1000   8000    32   46
# 206  2000   8000     0   52
# 207   512   8000    32   67
# 208  1000   4000     0   45
#
# [209 rows x 4 columns]

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data.to_csv("data.csv")
